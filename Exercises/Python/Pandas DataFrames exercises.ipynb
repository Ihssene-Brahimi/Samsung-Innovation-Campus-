# %% [markdown]
# # Pandas DataFrame exercises

# %%
# Import the numpy package under the name np
import numpy as np

# Import the pandas package under the name pd
import pandas as pd

# Import the matplotlib package under the name plt
import matplotlib.pyplot as plt
# %matplotlib inline

# Print the pandas version and the configuration
print(pd.__version__)
# Out:
# 1.1.5

# %% [markdown]
# ## DataFrame creation

# %% [markdown]
# ### Create an empty pandas DataFrame

# %%
# your code goes here

# %%
pd.DataFrame(data=[None],
             index=[None],
             columns=[None])

# %% [markdown]
# <img width="800" height="200" src="https://media1.tenor.com/images/47c1a3d90e55aa8f9f474ec1f68ea09c/tenor.gif?itemid=16810290" ></img>

# %% [markdown]
# ### Create a `marvel_df` pandas DataFrame with the given marvel data

# %%
marvel_data = [
    ['Spider-Man', 'male', 1962],
    ['Captain America', 'male', 1941],
    ['Wolverine', 'male', 1974],
    ['Iron Man', 'male', 1963],
    ['Thor', 'male', 1963],
    ['Thing', 'male', 1961],
    ['Mister Fantastic', 'male', 1961],
    ['Hulk', 'male', 1962],
    ['Beast', 'male', 1963],
    ['Invisible Woman', 'female', 1961],
    ['Storm', 'female', 1975],
    ['Namor', 'male', 1939],
    ['Hawkeye', 'male', 1964],
    ['Daredevil', 'male', 1964],
    ['Doctor Strange', 'male', 1963],
    ['Hank Pym', 'male', 1962],
    ['Scarlet Witch', 'female', 1964],
    ['Wasp', 'female', 1963],
    ['Black Widow', 'female', 1964],
    ['Vision', 'male', 1968]
]

# %%
df=pd.DataFrame(marvel_data)

df
# Out:
#                    0       1     2
# 0         Spider-Man    male  1962
# 1    Captain America    male  1941
# 2          Wolverine    male  1974
# 3           Iron Man    male  1963
# 4               Thor    male  1963
# 5              Thing    male  1961
# 6   Mister Fantastic    male  1961
# 7               Hulk    male  1962
# 8              Beast    male  1963
# 9    Invisible Woman  female  1961
# 10             Storm  female  1975
# 11             Namor    male  1939
# 12           Hawkeye    male  1964
# 13         Daredevil    male  1964
# 14    Doctor Strange    male  1963
# 15          Hank Pym    male  1962
# 16     Scarlet Witch  female  1964
# 17              Wasp  female  1963
# 18       Black Widow  female  1964
# 19            Vision    male  1968

# %% [markdown]
# ### Add column names to the `marvel_df`

# %%
# your code goes here
df.columns=["Name","Gender","yearOfRelease"]
df
# Out:
#                 Name  Gender  yearOfRelease
# 0         Spider-Man    male           1962
# 1    Captain America    male           1941
# 2          Wolverine    male           1974
# 3           Iron Man    male           1963
# 4               Thor    male           1963
# 5              Thing    male           1961
# 6   Mister Fantastic    male           1961
# 7               Hulk    male           1962
# 8              Beast    male           1963
# 9    Invisible Woman  female           1961
# 10             Storm  female           1975
# 11             Namor    male           1939
# 12           Hawkeye    male           1964
# 13         Daredevil    male           1964
# 14    Doctor Strange    male           1963
# 15          Hank Pym    male           1962
# 16     Scarlet Witch  female           1964
# 17              Wasp  female           1963
# 18       Black Widow  female           1964
# 19            Vision    male           1968

# %% [markdown]
# ### Add index names to the `marvel_df` (use the character name as index)

# %%
# your code goes here
df=df.set_index("Name")

# %% [markdown]
# ### Drop the name column as it's now the index

# %%
# your code goes here
df.drop("yearOfRelease",axis=1)

df
# Out:
#                   Gender  yearOfRelease
# Name
# Spider-Man          male           1962
# Captain America     male           1941
# Wolverine           male           1974
# Iron Man            male           1963
# Thor                male           1963
# Thing               male           1961
# Mister Fantastic    male           1961
# Hulk                male           1962
# Beast               male           1963
# Invisible Woman   female           1961
# Storm             female           1975
# Namor               male           1939
# Hawkeye             male           1964
# Daredevil           male           1964
# Doctor Strange      male           1963
# Hank Pym            male           1962
# Scarlet Witch     female           1964
# Wasp              female           1963
# Black Widow       female           1964
# Vision              male           1968

# %% [markdown]
# ### Drop 'Namor' and 'Hank Pym' rows

# %%
# your code goes here

df.drop(["Namor","Hank Pym"],inplace=True)

# %% [markdown]
# ## DataFrame selection, slicing and indexation

# %% [markdown]
# ### Show the first 5 elements on `marvel_df`

# %%
# your code goes here
df.head() #df.iloc[:5]
# Out:
#                 Gender  yearOfRelease
# Name
# Spider-Man        male           1962
# Captain America   male           1941
# Wolverine         male           1974
# Iron Man          male           1963
# Thor              male           1963

# %% [markdown]
# ### Show the last 5 elements on `marvel_df`

# %%
# your code goes here
df.tail()
# Out:
#                 Gender  yearOfRelease
# Name
# Doctor Strange    male           1963
# Scarlet Witch   female           1964
# Wasp            female           1963
# Black Widow     female           1964
# Vision            male           1968

# %% [markdown]
# ### Show just the sex of the first 5 elements on `marvel_df`

# %%
# your code goes here
#df["Gender"] or df.Gender
df.head().Gender
# Out:
# Name
# Spider-Man         male
# Captain America    male
# Wolverine          male
# Iron Man           male
# Thor               male
# Name: Gender, dtype: object

# %% [markdown]
# ### Show the first_appearance of all middle elements on `marvel_df`

# %%
# your code goes here
#loc is for the indexe that are in df (columns too)
df.iloc[1:-1].yearOfRelease
# Out:
# Name
# Captain America     1941
# Wolverine           1974
# Iron Man            1963
# Thor                1963
# Thing               1961
# Mister Fantastic    1961
# Hulk                1962
# Beast               1963
# Invisible Woman     1961
# Storm               1975
# Hawkeye             1964
# Daredevil           1964
# Doctor Strange      1963
# Scarlet Witch       1964
# Wasp                1963
# Black Widow         1964
# Name: yearOfRelease, dtype: int64

# %% [markdown]
# ### Show the first and last elements on `marvel_df`

# %%
# your code goes here
df[1:-1]
# Out:
#                   Gender  yearOfRelease
# Name
# Captain America     male           1941
# Wolverine           male           1974
# Iron Man            male           1963
# Thor                male           1963
# Thing               male           1961
# Mister Fantastic    male           1961
# Hulk                male           1962
# Beast               male           1963
# Invisible Woman   female           1961
# Storm             female           1975
# Hawkeye             male           1964
# Daredevil           male           1964
# Doctor Strange      male           1963
# Scarlet Witch     female           1964
# Wasp              female           1963
# Black Widow       female           1964

# %% [markdown]
# ## DataFrame manipulation and operations

# %% [markdown]
# ### Modify the `first_appearance` of 'Vision' to year 1964

# %%
# your code goes here

df.loc["Vision","yearOfRelease"]=1964



df
# Out:
#                   Gender  yearOfRelease
# Name
# Spider-Man          male           1962
# Captain America     male           1941
# Wolverine           male           1974
# Iron Man            male           1963
# Thor                male           1963
# Thing               male           1961
# Mister Fantastic    male           1961
# Hulk                male           1962
# Beast               male           1963
# Invisible Woman   female           1961
# Storm             female           1975
# Hawkeye             male           1964
# Daredevil           male           1964
# Doctor Strange      male           1963
# Scarlet Witch     female           1964
# Wasp              female           1963
# Black Widow       female           1964
# Vision              male           1964

# %% [markdown]
# ### Add a new column to `marvel_df` called 'years_since' with the years since `first_appearance`

# %%
# your code goes here
df["first_appearance"]= 2021-df["yearOfRelease"]
df
# Out:
#                   Gender  yearOfRelease  first_appearance
# Name
# Spider-Man          male           1962                59
# Captain America     male           1941                80
# Wolverine           male           1974                47
# Iron Man            male           1963                58
# Thor                male           1963                58
# Thing               male           1961                60
# Mister Fantastic    male           1961                60
# Hulk                male           1962                59
# Beast               male           1963                58
# Invisible Woman   female           1961                60
# Storm             female           1975                46
# Hawkeye             male           1964                57
# Daredevil           male           1964                57
# Doctor Strange      male           1963                58
# Scarlet Witch     female           1964                57
# ...

# %% [markdown]
# ## DataFrame boolean arrays (also called masks)

# %% [markdown]
# ### Given the `marvel_df` pandas DataFrame, make a mask showing the female characters

# %%
# your code goes here
df[df.Gender=="female"]
# Out:
#                  Gender  yearOfRelease  first_appearance
# Name
# Invisible Woman  female           1961                60
# Storm            female           1975                46
# Scarlet Witch    female           1964                57
# Wasp             female           1963                58
# Black Widow      female           1964                57

# %% [markdown]
# ### Given the `marvel_df` pandas DataFrame, get the male characters

# %%
# your code goes here

# %% [markdown]
# ### Given the `marvel_df` pandas DataFrame, get the characters with `first_appearance` after 1970

# %%
# your code goes here
df[df.yearOfRelease>1970]
# Out:
#            Gender  yearOfRelease  first_appearance
# Name
# Wolverine    male           1974                47
# Storm      female           1975                46

# %% [markdown]
# ### Given the `marvel_df` pandas DataFrame, get the female characters with `first_appearance` after 1970

# %%
# your code goes here
df[(df.Gender=="female") & (df.yearOfRelease>1970) ]
# Out:
#        Gender  yearOfRelease  first_appearance
# Name
# Storm  female           1975                46

# %% [markdown]
# ## DataFrame summary statistics

# %% [markdown]
# ### Show basic statistics of `marvel_df`

# %%
# your code goes here
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 18 entries, Spider-Man to Vision
# Data columns (total 3 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Gender            18 non-null     object
#  1   yearOfRelease     18 non-null     int64
#  2   first_appearance  18 non-null     int64
# dtypes: int64(2), object(1)
# memory usage: 1.2+ KB

# %% [markdown]
# ### Given the `marvel_df` pandas DataFrame, show the mean value of `first_appearance`

# %%
# your code goes here
df.describe()
# Out:
#        yearOfRelease  first_appearance
# count      18.000000         18.000000
# mean     1962.888889         58.111111
# std         6.720372          6.720372
# min      1941.000000         46.000000
# 25%      1962.000000         57.000000
# 50%      1963.000000         58.000000
# 75%      1964.000000         59.000000
# max      1975.000000         80.000000

# %%
df.describe(exclude=np.number)
# Out:
#        Gender
# count      18
# unique      2
# top      male
# freq       13

# %% [markdown]
# ### Given the `marvel_df` pandas DataFrame, show the min value of `first_appearance`

# %%
# your code goes here
df.yearOfRelease.min()
# Out:
# 1941

# %% [markdown]
# ### Given the `marvel_df` pandas DataFrame, get the characters with the min value of `first_appearance`

# %%
# your code goes here
df[df.yearOfRelease==df.yearOfRelease.min()]
# Out:
#                 Gender  yearOfRelease  first_appearance
# Name
# Captain America   male           1941                80

# %% [markdown]
# ## DataFrame basic plottings

# %% [markdown]
# ### Reset index names of `marvel_df`

# %%
# your code goes here
df.reset_index(inplace=True)

# %%
df.sort_values(by=["Name"])
# Out:
#                 Name  Gender  yearOfRelease  first_appearance
# 8              Beast    male           1963                58
# 16       Black Widow  female           1964                57
# 1    Captain America    male           1941                80
# 12         Daredevil    male           1964                57
# 13    Doctor Strange    male           1963                58
# 11           Hawkeye    male           1964                57
# 7               Hulk    male           1962                59
# 9    Invisible Woman  female           1961                60
# 3           Iron Man    male           1963                58
# 6   Mister Fantastic    male           1961                60
# 14     Scarlet Witch  female           1964                57
# 0         Spider-Man    male           1962                59
# 10             Storm  female           1975                46
# 5              Thing    male           1961                60
# ...

# %% [markdown]
# ### Plot the values of `first_appearance`

# %%
# your code goes here
df.Gender.value_counts()
# Out:
# male      13
# female     5
# Name: Gender, dtype: int64

# %%
from scipy.stats import mode
df.groupby("Gender")["yearOfRelease"].mean()
#df.groupby("Gender").agg({"yearOfRelease":"mean","first_appearance":"median"})
# Out:
# Gender
# female    1965.400000
# male      1962.230769
# Name: yearOfRelease, dtype: float64

# %% [markdown]
# ### Plot a histogram (plot.hist) with values of `first_appearance`

# %%
# your code goes here
